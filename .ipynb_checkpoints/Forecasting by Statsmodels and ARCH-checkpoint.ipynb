# %%
pip install arch
# Out:
# Requirement already satisfied: arch in /opt/anaconda3/lib/python3.9/site-packages (5.3.1)
# Requirement already satisfied: pandas>=1.0 in /opt/anaconda3/lib/python3.9/site-packages (from arch) (1.4.2)
# Requirement already satisfied: property-cached>=1.6.4 in /opt/anaconda3/lib/python3.9/site-packages (from arch) (1.6.4)
# Requirement already satisfied: scipy>=1.3 in /opt/anaconda3/lib/python3.9/site-packages (from arch) (1.7.3)
# Requirement already satisfied: statsmodels>=0.11 in /opt/anaconda3/lib/python3.9/site-packages (from arch) (0.13.2)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/lib/python3.9/site-packages (from arch) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.0->arch) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.0->arch) (2021.3)
# Requirement already satisfied: patsy>=0.5.2 in /opt/anaconda3/lib/python3.9/site-packages (from statsmodels>=0.11->arch) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in /opt/anaconda3/lib/python3.9/site-packages (from statsmodels>=0.11->arch) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/anaconda3/lib/python3.9/site-packages (from packaging>=21.3->statsmodels>=0.11->arch) (3.0.4)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels>=0.11->arch) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl


from datetime import datetime
import statsmodels.api as sm
from arch.unitroot import KPSS, ADF
from statsmodels.stats.outliers_influence import summary_table

import warnings
warnings.filterwarnings("ignore")

import yfinance as yf
yf.pdr_override()

# %%
symbol = '^GSPC' # input
start = '2019-01-01' # input 
end = '2022-07-22'  # input
df = yf.download(symbol, start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df_month = df.resample('M').last()

# %%
plt.figure(figsize = (12, 6))
plt.title('Close Prices between {} and {}'.format(
    start,
    end
))
df_month['Adj Close'].plot()
plt.ylabel('Price')
plt.xlabel('Date')
plt.show()

# %%
df_month.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2019-01-31  2685.489990  2708.949951  2678.649902  2704.100098  2704.100098
# 2019-02-28  2788.110107  2793.729980  2782.510010  2784.489990  2784.489990
# 2019-03-31  2828.270020  2836.030029  2819.229980  2834.399902  2834.399902
# 2019-04-30  2937.139893  2948.219971  2924.110107  2945.830078  2945.830078
# 2019-05-31  2766.149902  2768.979980  2750.520020  2752.060059  2752.060059
#
#                 Volume
# Date
# 2019-01-31  4917650000
# 2019-02-28  4396930000
# 2019-03-31  3740700000
# 2019-04-30  3919330000
# 2019-05-31  3981020000

# %%
df_month.index.freq

# %%
df_month=df_month.rename(columns={"Close": "Price"}, inplace=False)
df_month
df2 = df_month.drop(columns = ['Open', 'High', 'Low', 'Adj Close', 'Volume'])
df2
# Out:
#                   Price
# Date
# 2019-01-31  2704.100098
# 2019-02-28  2784.489990
# 2019-03-31  2834.399902
# 2019-04-30  2945.830078
# 2019-05-31  2752.060059
# 2019-06-30  2941.760010
# 2019-07-31  2980.379883
# 2019-08-31  2926.459961
# 2019-09-30  2976.739990
# 2019-10-31  3037.560059
# 2019-11-30  3140.979980
# 2019-12-31  3230.780029
# 2020-01-31  3225.520020
# 2020-02-29  2954.219971
# 2020-03-31  2584.590088
# 2020-04-30  2912.429932
# 2020-05-31  3044.310059
# 2020-06-30  3100.290039
# 2020-07-31  3271.120117
# 2020-08-31  3500.310059
# 2020-09-30  3363.000000
# 2020-10-31  3269.959961
# 2020-11-30  3621.629883
# 2020-12-31  3756.070068
# 2021-01-31  3714.239990
# 2021-02-28  3811.149902
# 2021-03-31  3972.889893
# 2021-04-30  4181.169922
# 2021-05-31  4204.109863
# 2021-06-30  4297.500000
# 2021-07-31  4395.259766
# 2021-08-31  4522.680176
# 2021-09-30  4307.540039
# 2021-10-31  4605.379883
# 2021-11-30  4567.000000
# 2021-12-31  4766.180176
# 2022-01-31  4515.549805
# 2022-02-28  4373.939941
# 2022-03-31  4530.410156
# 2022-04-30  4131.930176
# 2022-05-31  4132.149902
# 2022-06-30  3785.379883
# 2022-07-31  3998.949951

# %%
plt.rc("figure", figsize=(10,6))
sm.tsa.seasonal_decompose(df2.Price).plot()
print("Dickey–Fuller test: p=%f" % sm.tsa.stattools.adfuller(df2.Price)[1])
plt.show()
# Out:
# Dickey–Fuller test: p=0.620703

# %%
ADF(df2.Price)
# Out:
# <class 'arch.unitroot.unitroot.ADF'>
# """
#    Augmented Dickey-Fuller Results
# =====================================
# Test Statistic                 -1.318
# P-value                         0.621
# Lags                                0
# -------------------------------------
#
# Trend: Constant
# Critical Values: -3.60 (1%), -2.93 (5%), -2.60 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
# """

# %%
df2['log_rtn'] = np.log(df2.Price/df2.Price.shift(1))
print("Dickey–Fuller test: p=%f" % sm.tsa.stattools.adfuller(df2.log_rtn[13:])[1])

# STL-decomposition
sm.tsa.seasonal_decompose(df2.log_rtn[13:]).plot()   

plt.show()
# Out:
# Dickey–Fuller test: p=0.774782

# %%
df2=df2.dropna(axis=0)
df2.isnull().sum()
# Out:
# Price      0
# log_rtn    0
# dtype: int64

# %%
fig, axs = plt.subplots(2)
sm.graphics.tsa.plot_pacf(df2.log_rtn, lags=20, ax=axs[0])
axs[0].set_ylabel('R')
axs[0].set_xlabel('Lag')
sm.graphics.tsa.plot_acf(df2.log_rtn, lags=20, ax=axs[1]);
axs[1].set_ylabel('R')
axs[1].set_xlabel('Lag')
fig.tight_layout()

# %%
from itertools import product

Qs = range(0, 3)
qs = range(0, 3)
Ps = range(0, 3)
ps = range(0, 3)
D=1
d=1
parameters = product(ps, qs, Ps, Qs)
parameters_list = list(parameters)
len(parameters_list)

# Model Selection
results = []
best_aic = float("inf")
warnings.filterwarnings('ignore')
for param in parameters_list:
    try:
        model=sm.tsa.statespace.SARIMAX(df2.Price, order=(param[0], d, param[1]), 
                                        seasonal_order=(param[2], D, param[3], 12)).fit(disp=-1)
    except ValueError:
        print('wrong parameters:', param)
        continue
    
    bic = model.bic
    best_bic = bic   
    if bic < best_bic:
        best_model = model
        best_bic = bic
        best_param = param
    results.append([param, model.bic])

# %%
# Best Models
result_table = pd.DataFrame(results)
result_table.columns = ['parameters', 'bic']
print(result_table.sort_values(by = 'bic', ascending=True).head())
bic_model=sm.tsa.statespace.SARIMAX(df2.Price, order=(1,1,1), 
                                        seasonal_order=(1,1,1, 12)).fit(disp=-1)
print(bic_model.summary())
# Out:
#       parameters         bic
# 1   (0, 0, 0, 1)  407.663771
# 3   (0, 0, 1, 0)  408.029869
# 0   (0, 0, 0, 0)  409.067238
# 28  (1, 0, 0, 1)  409.974834
# 10  (0, 1, 0, 1)  410.219784
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              Price   No. Observations:                   42
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 12)   Log Likelihood                -199.852
# Date:                            Mon, 08 Aug 2022   AIC                            409.704
# Time:                                    16:52:04   BIC                            416.541
# Sample:                                02-28-2019   HQIC                           411.845
#                                      - 07-31-2022
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4410      0.994     -0.444      0.657      -2.390       1.508
# ma.L1          0.2347      0.977      0.240      0.810      -1.679       2.149
# ar.S.L12      -0.0763      1.044     -0.073      0.942      -2.123       1.970
# ma.S.L12      -0.8250      5.602     -0.147      0.883     -11.805      10.155
# sigma2      4.014e+04   1.76e+05      0.228      0.820   -3.05e+05    3.85e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.06   Jarque-Bera (JB):                 1.73
# Prob(Q):                              0.81   Prob(JB):                         0.42
# Heteroskedasticity (H):               1.79   Skew:                            -0.59
# Prob(H) (two-sided):                  0.37   Kurtosis:                         3.19
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# STL-decomposition
plt.figure(figsize=(15,7))
plt.subplot(211)
bic_model.resid[13:].plot()
plt.ylabel('Residuals')
ax = plt.subplot(212)
sm.graphics.tsa.plot_acf(bic_model.resid[13:].values.squeeze(), lags=13, ax=ax)

print("Dickey–Fuller test:: p=%f" % sm.tsa.stattools.adfuller(bic_model.resid[13:])[1])

plt.tight_layout()
plt.show()
# Out:
# Dickey–Fuller test:: p=0.015456

# %%
date_list = [datetime(2022, 8, 31),
             datetime(2022, 9, 30),datetime(2022, 10, 31), datetime(2022, 11, 30),datetime(2022, 12, 31),
             datetime(2023, 1, 31), datetime(2023, 2, 28), datetime(2023, 3, 31), datetime(2023, 4, 30), 
             datetime(2023, 5, 31), datetime(2023, 6, 30), datetime(2023, 7, 31), datetime(2023, 8, 31),
             datetime(2023, 9, 30),datetime(2023, 10, 31), datetime(2023, 11, 30),datetime(2023, 12, 31)]
future = pd.DataFrame(index=date_list, columns= df2.columns)
df2 = pd.concat([df2, future])
df2['forecast'] = bic_model.predict(start=20, end=144)

# %%
plt.figure(figsize=(15,7))
df2.Price.plot()
df2.forecast.plot(color='r', ls='--', label='Predicted Price')
plt.legend()
plt.title(symbol + ' Price Monthly')
plt.ylabel('Price in USD')
plt.show()

# %%
predictions_int = bic_model.get_forecast(steps=24)
predictions_int.predicted_mean
# Out:
# 2022-08-31    4055.850128
# 2022-09-30    3980.416087
# 2022-10-31    4043.439460
# 2022-11-30    4200.028898
# 2022-12-31    4337.588695
# 2023-01-31    4243.283366
# 2023-02-28    4177.124400
# 2023-03-31    4170.316888
# 2023-04-30    4257.877787
# 2023-05-31    4253.318517
# 2023-06-30    4266.415236
# 2023-07-31    4393.237479
# 2023-08-31    4488.745989
# 2023-09-30    4388.000457
# 2023-10-31    4475.397691
# 2023-11-30    4614.265510
# 2023-12-31    4757.782599
# 2024-01-31    4650.999454
# 2024-02-29    4579.330265
# 2024-03-31    4584.868436
# 2024-04-30    4635.405492
# 2024-05-31    4631.189743
# 2024-06-30    4616.847880
# 2024-07-31    4750.282492
# Freq: M, Name: predicted_mean, dtype: float64

# %%
predictions_int.conf_int()
# Out:
#             lower Price  upper Price
# 2022-08-31  3633.586423  4478.113833
# 2022-09-30  3441.172437  4519.659738
# 2022-10-31  3387.391318  4699.487602
# 2022-11-30  3453.237509  4946.820286
# 2022-12-31  3506.719523  5168.457867
# 2023-01-31  3337.421302  5149.145430
# 2023-02-28  3201.711361  5152.537438
# 2023-03-31  3133.487487  5207.146290
# 2023-04-30  3163.018487  5352.737086
# 2023-05-31  3103.368099  5403.268934
# 2023-06-30  3063.907253  5468.923218
# 2023-07-31  3140.328621  5646.146338
# 2023-08-31  3159.944205  5817.547772
# 2023-09-30  2993.144830  5782.856083
# 2023-10-31  3015.070567  5935.724816
# 2023-11-30  3092.353886  6136.177135
# 2023-12-31  3176.103824  6339.461375
# 2024-01-31  3012.274121  6289.724787
# 2024-02-29  2884.797611  6273.862920
# 2024-03-31  2842.333257  6327.403615
# 2024-04-30  2846.180229  6424.630756
# 2024-05-31  2796.445892  6465.933595
# 2024-06-30  2737.707415  6495.988345
# 2024-07-31  2827.732856  6672.832127

# %%
conf_df = pd.concat([df2['Price'],predictions_int.predicted_mean, predictions_int.conf_int()], axis = 1)

conf_df.head()
# Out:
#                   Price  predicted_mean  lower Price  upper Price
# 2019-02-28   2784.48999             NaN          NaN          NaN
# 2019-03-31  2834.399902             NaN          NaN          NaN
# 2019-04-30  2945.830078             NaN          NaN          NaN
# 2019-05-31  2752.060059             NaN          NaN          NaN
# 2019-06-30   2941.76001             NaN          NaN          NaN

# %%
conf_df = conf_df.rename(columns={0: 'Predictions', 'lower MI': 'Lower CI', 'upper MI': 'Upper CI'})
conf_df.head()
# Out:
#                   Price  predicted_mean  lower Price  upper Price
# 2019-02-28   2784.48999             NaN          NaN          NaN
# 2019-03-31  2834.399902             NaN          NaN          NaN
# 2019-04-30  2945.830078             NaN          NaN          NaN
# 2019-05-31  2752.060059             NaN          NaN          NaN
# 2019-06-30   2941.76001             NaN          NaN          NaN

# %%
fig = plt.figure(figsize = (16,8))
ax1 = fig.add_subplot(111)


x = conf_df.index.values


upper = conf_df['upper Price']
lower = conf_df['lower Price']

conf_df['Price'].plot(color = 'blue', label = 'Actual')
conf_df['predicted_mean'].plot(color = 'red',label = 'Predicted' )
upper.plot(color = 'grey', label = 'Upper CI')
lower.plot(color = 'grey', label = 'Lower CI')

# plot the legend for the first plot
plt.legend(loc = 'lower left', fontsize = 12)


# fill between the conf intervals
plt.fill_between(x, lower, upper, color='green')
